# %%
from sqlalchemy import create_engine, text

# %%
database_name = 'scooters'

connection_string = f"postgresql://postgres:postgres@localhost:5432/{database_name}"

# %%
engine = create_engine(connection_string)

# %%
query = '''
SELECT *
FROM scooters
LIMIT 100;
'''

with engine.connect() as connection: result = connection.execute(text(query))

# %%
result.fetchone()
# Out:
# (datetime.datetime(2019, 5, 23, 1, 47, 12), Decimal('36.158200'), Decimal('-86.783800'), 'Poweredfa77b89f-5654-5ead-844c-192f728bae5f', 'Powered', Decimal('4.00'), 'scooter', Decimal('0.06'), 'Jump')

# %%
import pandas as pd

# %%
with engine.connect() as connection:    
    scooters = pd.read_sql(text(query), con = connection)

# %%
scooters
# Out:
#                pubdatetime   latitude  longitude  \
# 0  2019-05-23 01:47:12.000  36.158200 -86.783800
# 1  2019-05-23 01:47:12.000  36.163600 -86.785100
# 2  2019-05-23 01:47:12.000  36.120000 -86.753500
# 3  2019-05-23 01:47:12.000  36.119900 -86.753200
# 4  2019-05-23 01:47:12.000  36.119600 -86.753000
# ..                     ...        ...        ...
# 95 2019-05-23 01:47:13.330  36.152336 -86.791010
# 96 2019-05-23 01:47:13.377  36.177346 -86.749916
# 97 2019-05-23 01:47:13.383  36.153029 -86.783057
# 98 2019-05-23 01:47:13.437  36.143980 -86.797725
# 99 2019-05-23 01:47:13.587  36.151212 -86.804391
#
#                                          sumdid sumdtype  chargelevel  \
# 0   Poweredfa77b89f-5654-5ead-844c-192f728bae5f  Powered          4.0
# 1   Powered30ef1232-1eed-57fb-b558-07356d1c4eea  Powered         22.0
# 2   Poweredbd99fad9-84ba-56ac-bfbb-eda31e9ced09  Powered         24.0
# 3   Powered67a9d1a9-f305-5384-b8c3-8ff059f469a6  Powered          2.0
# ...

# %%
query2 = '''
SELECT *
FROM trips
LIMIT 50;
'''

# %%
with engine.connect() as connection:    
    trips = pd.read_sql(text(query2), con = connection)

# %%
trips
# Out:
#               pubtimestamp    companyname triprecordnum  \
# 0  2019-06-26 19:18:17.223           Bird       BRD1107
# 1  2019-06-26 19:18:17.223           Bird       BRD1109
# 2  2019-06-26 19:18:17.223           Bird       BRD1108
# 3  2019-06-26 19:18:17.223           Bird       BRD1111
# 4  2019-06-26 19:18:17.223           Bird       BRD1114
# 5  2019-06-26 19:21:56.810           Lyft        LFT654
# 6  2019-06-26 19:58:19.153           Bird       BRD1241
# 7  2019-06-26 19:18:17.223           Bird       BRD1110
# 8  2019-06-26 19:18:17.223           Bird       BRD1105
# 9  2019-06-26 19:18:23.673           Lyft        LFT651
# 10 2019-06-26 19:18:52.197           Lyft        LFT652
# 11 2019-06-26 19:18:58.800           Lyft        LFT653
# 12 2019-06-26 19:19:24.920           SPIN        SPI116
# 13 2019-06-26 19:19:24.920           SPIN        SPI118
# 14 2019-06-26 19:22:02.280           Lyft        LFT655
# 15 2019-06-26 19:23:06.000         Gotcha         GOT40
# ...

# %% [markdown]
# SCOOTERS PER COMPANY BY MONTH - MAY

# %%
query3= '''
SELECT companyname, sumdgroup, COUNT(DISTINCT sumdid)
FROM scooters
WHERE sumdgroup ILIKE '%scooter%'
AND pubdatetime BETWEEN '2019-05-01' AND '2019-05-30'
GROUP BY companyname, sumdgroup;
'''

with engine.connect() as connection:    
    scoots_in_May = pd.read_sql(text(query3), con = connection)

# %%
scoots_in_May.sort_values(by = 'count', ascending = False)
# Out:
#   companyname sumdgroup  count
# 0        Bird   scooter   3012
# 4        Lime   scooter   1617
# 5        Lyft   scooter   1374
# 3        Jump   scooter    976
# 6        Spin   Scooter    630
# 1        Bolt   Scooter    345
# 2      Gotcha   Scooter    223

# %%
scoots_in_May.to_csv('data.csv')

# %% [markdown]
# SCOOTERS PER COMPANY BY MONTH - JUNE

# %%
query8 = '''
SELECT companyname, sumdgroup, COUNT(DISTINCT sumdid)
FROM scooters
WHERE sumdgroup ILIKE '%scooter%'
AND pubdatetime BETWEEN '2019-06-01' AND '2019-06-30'
GROUP BY companyname, sumdgroup;
'''

with engine.connect() as connection:    
    scoots_in_June = pd.read_sql(text(query8), con = connection)

# %%
scoots_in_June.sort_values(by = 'count', ascending = False)
# Out:
#   companyname sumdgroup  count
# 0        Bird   scooter   2901
# 4        Lime   scooter   1450
# 5        Lyft   scooter   1147
# 3        Jump   scooter   1036
# 6        Spin   Scooter    713
# 1        Bolt   Scooter    333
# 2      Gotcha   Scooter    223

# %% [markdown]
# SCOOTERS PER COMPANY BY MONTH - JULY

# %%
query9 = '''
SELECT companyname, sumdgroup, COUNT(DISTINCT sumdid)
FROM scooters
WHERE sumdgroup ILIKE '%scooter%'
AND pubdatetime BETWEEN '2019-07-01' AND '2019-07-31'
GROUP BY companyname, sumdgroup;
'''

with engine.connect() as connection:    
    scoots_in_July = pd.read_sql(text(query9), con = connection)

# %%
scoots_in_July.sort_values(by = 'count', ascending = False)
# Out:
#   companyname sumdgroup  count
# 0        Bird   scooter   2553
# 3        Jump   scooter   1206
# 5        Lyft   scooter   1025
# 4        Lime   scooter    894
# 6        Spin   Scooter    570
# 1        Bolt   Scooter    273
# 2      Gotcha   Scooter    224

# %% [markdown]
# IMPORTING BUS STOPS DATAFRAME

# %%
import pandas as pd
hub_spots = pd.read_csv('../data/Regional_Transportation_Authority_Bus_Stops.csv')

# %%
hub_spots
# Out:
#     Stop ID Number Stop Abbreviation                           Stop Name  \
# 0             4418           MCC4_20     MUSIC CITY CENTRAL 4TH - BAY 20
# 1             4422            MCC5_6      MUSIC CITY CENTRAL 5TH - BAY 6
# 2             4249              21WE       21ST AVE PAST WEST END AVE SB
# 3             4184             MCSMJ  MUSIC CITY STAR MT. JULIET STATION
# 4             4425            MCC5_8      MUSIC CITY CENTRAL 5TH - BAY 8
# ..             ...               ...                                 ...
# 83            4185             MCSMS    MUSIC CITY STAR MARTHA'S STATION
# 84            4430            MCC5_7      MUSIC CITY CENTRAL 5TH - BAY 7
# 85            5053            DRCRPR            DRAKES CREEK PARK-N-RIDE
# 86            4249              21WE       21ST AVE PAST WEST END AVE SB
# 87            4431           MCC5_11     MUSIC CITY CENTRAL 5TH - BAY 11
#
#     Bench  Shelter  Line Number               Line Name  \
# ...

# %% [markdown]
# AVERAGE DURATION OF SCOOTERS

# %%
query20 = '''
SELECT DISTINCT ROUND(AVG(tripduration), 2) as avg_duration, COUNT(sumdid) as scoots
FROM trips
WHERE startdate BETWEEN '2019-05-01' and '2019-05-31'
AND tripduration >= 1.0 
AND tripduration <= 1440
AND startdate BETWEEN '2019-05-01' and '2019-05-31'
AND tripduration >= 1.0 
AND tripduration <= 1440
'''

with engine.connect() as connection:    
    avg_duration_of_scoots = pd.read_sql(text(query20), con = connection)
    
avg_duration_of_scoots
# Out:
#    avg_duration  scoots
# 0         26.34  220004

# %% [markdown]
# BREAKDOWN OF SCOOTER USAGE BY MORNING, AFTERNOON, EVENING RUSH HOUR, AND NIGHTTIME

# %% [markdown]
# Morning - 7-10

# %%
query21 = '''
SELECT DISTINCT sumdid, starttime, endtime
FROM trips
WHERE starttime BETWEEN '06:00:00' AND '10:00:00'
AND endtime BETWEEN '06:00:00' AND '10:00:00'
AND startdate BETWEEN '2019-05-01' and '2019-05-31'
AND tripduration >= 1.0 
AND tripduration <= 1440
'''

with engine.connect() as connection:    
    morning_scoots = pd.read_sql(text(query21), con = connection)
    
morning_scoots
# Out:
#                                             sumdid starttime   endtime
# 0     Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619  06:09:42  06:18:06
# 1     Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619  06:37:26  06:38:17
# 2     Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619  07:12:07  07:32:29
# 3     Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619  08:55:01  09:03:01
# 4     Powered-01a24436-0315-e1bb-7ce0-d081d05dff7d  07:17:47  07:25:07
# ...                                            ...       ...       ...
# 6330                          PoweredZZNTWU4QI7MLI  06:11:17  06:42:07
# 6331                          PoweredZZNTWU4QI7MLI  06:15:03  06:24:10
# 6332                          PoweredZZNTWU4QI7MLI  06:30:20  06:40:49
# 6333                          PoweredZZQOO54WD4AJT  06:53:54  06:59:44
# 6334                          PoweredZZQOO54WD4AJT  09:00:47  09:07:11
#
# [6335 rows x 3 columns]

# %% [markdown]
# lunch/afternoonish - 11-2

# %%
query22 = '''
SELECT DISTINCT sumdid, starttime, endtime
FROM trips
WHERE starttime BETWEEN '11:00:00' AND '14:00:00'
AND endtime BETWEEN '11:00:00' AND '14:00:00'
'''

with engine.connect() as connection:    
    afternoon_scoots = pd.read_sql(text(query22), con = connection)
    
afternoon_scoots
# Out:
#                                              sumdid starttime   endtime
# 0      Powered-03be23ca-d43b-222f-be54-e44b5b4690df  12:56:00  13:20:09
# 1      Powered-046201fb-6532-1f37-6334-3612fb1e61f7  13:37:16  13:41:57
# 2      Powered-046201fb-6532-1f37-6334-3612fb1e61f7  13:38:50  13:45:36
# 3      Powered-0555d61d-1c59-4219-edf3-0f00e286629a  11:30:31  11:45:50
# 4      Powered-0555d61d-1c59-4219-edf3-0f00e286629a  12:37:13  12:54:57
# ...                                             ...       ...       ...
# 18831                          PoweredZZQ7FMUUD6ULV  12:43:50  13:11:19
# 18832                          PoweredZZQOO54WD4AJT  11:55:09  11:58:50
# 18833                          PoweredZZQOO54WD4AJT  12:46:30  12:49:33
# 18834                          PoweredZZQOO54WD4AJT  12:54:53  13:07:54
# 18835                          PoweredZZQOO54WD4AJT  12:58:41  13:03:12
#
# [18836 rows x 3 columns]

# %% [markdown]
# evening/rushhour - 3-6

# %%
query23 = '''
SELECT DISTINCT sumdid, starttime, endtime
FROM trips
WHERE starttime BETWEEN '15:00:00' AND '18:00:00'
AND endtime BETWEEN '15:00:00' AND '18:00:00'
'''

with engine.connect() as connection:    
    evening_scoots = pd.read_sql(text(query23), con = connection)
    
evening_scoots
# Out:
#                      sumdid        starttime          endtime
# 0      PoweredWIUPNXR5V37TV         17:01:50         17:03:02
# 1             Powered347056  17:25:41.306666  17:39:12.396666
# 2            Powered2051884         17:44:03         17:54:17
# 3      PoweredDI5QDAU4OEJM7         16:37:06         17:02:10
# 4      Powered276XA7F25HW6H         15:39:45         16:13:15
# ...                     ...              ...              ...
# 88715          PoweredL75M3  16:54:33.926666  17:03:24.600000
# 88716  PoweredX5F3RKUYOY6RI         16:04:04         16:22:43
# 88717         Powered980721  16:14:52.190000  16:25:51.843333
# 88718         Powered782785  15:30:46.170000  16:04:54.820000
# 88719  PoweredVW4PNNV3UKVWX         16:11:52         16:22:38
#
# [88720 rows x 3 columns]

# %% [markdown]
# nightime/partytime 7-12pm

# %%
query24 = '''
SELECT sumdid, starttime, endtime
FROM trips
WHERE starttime BETWEEN '19:00:00' AND '24:00:00'
AND endtime BETWEEN '19:00:00' AND '24:00:00'
AND startdate BETWEEN '2019-05-01' and '2019-05-31'
AND tripduration >= 1.0 
AND tripduration <= 1440
'''

with engine.connect() as connection:    
    nightly_scoots = pd.read_sql(text(query24), con = connection)
    
nightly_scoots
# Out:
#                                              sumdid        starttime  \
# 0                                     Powered935160  21:51:21.833333
# 1                                      Powered2VPG6  21:43:59.020000
# 2                                      PoweredM3I1J  22:51:00.006666
# 3                              PoweredLEMU3ZKJOGCQ7         22:53:27
# 4                                      PoweredMWUV2  23:55:06.483333
# ...                                             ...              ...
# 64374  Powered-7b003f0c-6364-5ed9-9e0e-b33e8b18aec4         23:50:08
# 64375  Powered-a31dc125-5151-18b2-ac70-0301656484bd         23:53:25
# 64376                                Powered9858918         23:49:13
# 64377                                Powered1098749         21:55:36
# 64378                                Powered3400377         23:45:16
#
#                endtime
# 0      23:00:14.700000
# 1      21:47:04.506666
# 2      22:58:43.726666
# 3             23:02:52
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics

# %%
sns.barplot(data = scoots_in_May, x = "count", y = "companyname");

# %%
sns.barplot(data = scoots_in_June, x = "count", y = "companyname")
# Out:
# <AxesSubplot:xlabel='count', ylabel='companyname'>

# %%
sns.barplot(data = scoots_in_July, x = "count", y = "companyname");

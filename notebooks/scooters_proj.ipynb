# %% [markdown]
# scooters count: 73,414,043

# %% [markdown]
# trips count: 565,522

# %%
from sqlalchemy import create_engine, text

# %%
database_name = 'scooters'

connection_string = f"postgresql://postgres:postgres@localhost:5432/{database_name}"

# %%
engine = create_engine(connection_string)

# %%
query = '''
SELECT *
FROM scooters
LIMIT 10;
'''

with engine.connect() as connection: result = connection.execute(text(query))

# %%
result.fetchone()
# Out:
# (datetime.datetime(2019, 5, 23, 1, 47, 12), Decimal('36.158200'), Decimal('-86.783800'), 'Poweredfa77b89f-5654-5ead-844c-192f728bae5f', 'Powered', Decimal('4.00'), 'scooter', Decimal('0.06'), 'Jump')

# %%
import pandas as pd

# %%
with engine.connect() as connection:    
    scooters = pd.read_sql(text(query), con = connection)

# %%
scooters
# Out:
#           pubdatetime  latitude  longitude  \
# 0 2019-05-23 01:47:12   36.1582   -86.7838
# 1 2019-05-23 01:47:12   36.1636   -86.7851
# 2 2019-05-23 01:47:12   36.1200   -86.7535
# 3 2019-05-23 01:47:12   36.1199   -86.7532
# 4 2019-05-23 01:47:12   36.1196   -86.7530
# 5 2019-05-23 01:47:12   36.1630   -86.7742
# 6 2019-05-23 01:47:12   36.1576   -86.7964
# 7 2019-05-23 01:47:12   36.1364   -86.7885
# 8 2019-05-23 01:47:12   36.1486   -86.8087
# 9 2019-05-23 01:47:12   36.1376   -86.8001
#
#                                         sumdid sumdtype  chargelevel  \
# 0  Poweredfa77b89f-5654-5ead-844c-192f728bae5f  Powered          4.0
# 1  Powered30ef1232-1eed-57fb-b558-07356d1c4eea  Powered         22.0
# 2  Poweredbd99fad9-84ba-56ac-bfbb-eda31e9ced09  Powered         24.0
# 3  Powered67a9d1a9-f305-5384-b8c3-8ff059f469a6  Powered          2.0
# 4  Powered0d0ca44f-f321-5000-a4a7-e9ac01654eab  Powered         33.0
# 5  Poweredd4c9fd67-53a0-5426-8aa4-795ee4c614be  Powered         52.0
# ...

# %%
query2 = '''
SELECT *
FROM trips
LIMIT 10;
'''

# %%
with engine.connect() as connection:    
    trips = pd.read_sql(text(query2), con = connection)

# %%
trips
# Out:
#              pubtimestamp companyname triprecordnum         sumdid  \
# 0 2019-06-26 19:18:17.223        Bird       BRD1107   PoweredAZRVL
# 1 2019-06-26 19:18:17.223        Bird       BRD1109   Powered89UBD
# 2 2019-06-26 19:18:17.223        Bird       BRD1108   PoweredPN85S
# 3 2019-06-26 19:18:17.223        Bird       BRD1111   Powered4PDHT
# 4 2019-06-26 19:18:17.223        Bird       BRD1114   PoweredL1I49
# 5 2019-06-26 19:21:56.810        Lyft        LFT654  Powered589569
# 6 2019-06-26 19:58:19.153        Bird       BRD1241   PoweredD9RT9
# 7 2019-06-26 19:18:17.223        Bird       BRD1110   Powered6IHEL
# 8 2019-06-26 19:18:17.223        Bird       BRD1105   PoweredY88L8
# 9 2019-06-26 19:18:23.673        Lyft        LFT651  Powered010653
#
#    tripduration  tripdistance   startdate        starttime     enddate  \
# 0       5.00000       0.00000  2019-06-26  19:15:04.433333  2019-06-26
# 1       8.00000       0.00000  2019-06-26  19:11:46.526666  2019-06-26
# ...

# %% [markdown]
# 1. During this period, seven companies offered scooters. How many scooters did each company have in this time frame?

# %%
query3 = '''
SELECT companyname, sumdgroup, COUNT(DISTINCT sumdid)
FROM scooters
WHERE sumdgroup ILIKE '%scooter%'
GROUP BY companyname, sumdgroup;
'''

with engine.connect() as connection:    
    Q1 = pd.read_sql(text(query3), con = connection)

# %%
Q1
# Out:
#   companyname sumdgroup  count
# 0        Bird   scooter   3860
# 1        Bolt   Scooter    360
# 2      Gotcha   Scooter    224
# 3        Jump   scooter   1210
# 4        Lime   scooter   1818
# 5        Lyft   scooter   1735
# 6        Spin   Scooter    805

# %%
query4 = '''
SELECT companyname, COUNT(DISTINCT sumdid) 
FROM trips
WHERE startdate >= '2019-01-01' AND starttime <= '2019-12-31 23:59:59'
GROUP BY companyname;
'''

with engine.connect() as connection:    
    Q1_1 = pd.read_sql(text(query4), con = connection)

# %% [markdown]
# Did scooter usage vary by company? Did the number for each company change over time?

# %%
Q1_1
# Out:
#      companyname  count
# 0           Bird   3766
# 1  Bolt Mobility    356
# 2         Gotcha    166
# 3           JUMP    450
# 4           Lime   1788
# 5           Lyft   1725
# 6           SPIN    754

# %% [markdown]
# 2. According to Second Substitute Bill BL2018-1202 (as amended) (https://web.archive.org/web/20181019234657/https://www.nashville.gov/Metro-Clerk/Legislative/Ordinances/Details/7d2cf076-b12c-4645-a118-b530577c5ee8/2015-2019/BL2018-1202.aspx), all permitted operators will first clean data before providing or reporting data to Metro. Data processing and cleaning shall include:
# * Removal of staff servicing and test trips
# * Removal of trips below one minute
# * Trip lengths are capped at 24 hours
# Are the scooter companies in compliance with the second and third part of this rule?

# %%
query5 ='''
SELECT companyname, tripduration 
FROM trips
WHERE tripduration < 0.6000
ORDER BY companyname ASC;
'''

with engine.connect() as connection:    
    Q2_time_under_minute = pd.read_sql(text(query5), con = connection)

# %%
Q2_time_under_minute
# Out:
#      companyname  tripduration
# 0           Bird      0.000000
# 1           Bird      0.000000
# 2           Bird      0.000000
# 3           Bird      0.000000
# 4           Bird      0.000000
# ...          ...           ...
# 7075        Lyft      0.469050
# 7076        Lyft      0.447700
# 7077        Lyft      0.451617
# 7078        Lyft      0.575183
# 7079        Lyft      0.199767
#
# [7080 rows x 2 columns]

# %%
query6 ='''
SELECT companyname, tripduration 
FROM trips
WHERE tripduration < 0.60000
AND companyname = 'Lyft'
ORDER BY companyname ASC;
'''

with engine.connect() as connection:    
    Q2_time_under_minute_lyft = pd.read_sql(text(query6), con = connection)

# %%
Q2_time_under_minute_lyft
# Out:
#      companyname  tripduration
# 0           Lyft      0.472400
# 1           Lyft      0.199267
# 2           Lyft      0.462700
# 3           Lyft      0.172950
# 4           Lyft      0.531450
# ...          ...           ...
# 2451        Lyft      0.460233
# 2452        Lyft      0.350850
# 2453        Lyft      0.169883
# 2454        Lyft      0.219283
# 2455        Lyft      0.515733
#
# [2456 rows x 2 columns]

# %%
query7 ='''
SELECT companyname, tripduration 
FROM trips
WHERE tripduration < 0.60000
AND companyname = 'Bird'
ORDER BY companyname ASC;
'''

with engine.connect() as connection:    
    Q2_time_under_minute_Bird = pd.read_sql(text(query7), con = connection)

# %%
Q2_time_under_minute_Bird
# Out:
#      companyname  tripduration
# 0           Bird           0.0
# 1           Bird           0.0
# 2           Bird           0.0
# 3           Bird           0.0
# 4           Bird           0.0
# ...          ...           ...
# 3958        Bird           0.0
# 3959        Bird           0.0
# 3960        Bird           0.0
# 3961        Bird           0.0
# 3962        Bird           0.0
#
# [3963 rows x 2 columns]

# %%
query8 ='''
SELECT companyname, tripduration 
FROM trips
WHERE tripduration < 0.60000
AND companyname = 'Spin'
ORDER BY companyname ASC;
'''

with engine.connect() as connection:    
    Q2_time_under_minute_Spin = pd.read_sql(text(query8), con = connection)

# %%
Q2_time_under_minute_Spin
# Out:
# Empty DataFrame
# Columns: [companyname, tripduration]
# Index: []

# %%
query9 ='''
SELECT companyname, tripduration 
FROM trips
WHERE tripduration < 0.60000
AND companyname = 'JUMP'
ORDER BY companyname ASC;
'''

with engine.connect() as connection:    
    Q2_time_under_minute_Jump = pd.read_sql(text(query9), con = connection)

# %%
Q2_time_under_minute_Jump
# Out:
# Empty DataFrame
# Columns: [companyname, tripduration]
# Index: []

# %%
query10 ='''
SELECT companyname, tripduration 
FROM trips
WHERE tripduration < 0.6000
AND companyname = 'Lime'
ORDER BY companyname ASC;
'''

with engine.connect() as connection:    
    Q2_time_under_minute_Lime = pd.read_sql(text(query10), con = connection)

# %%
Q2_time_under_minute_Lime
# Out:
#     companyname  tripduration
# 0          Lime           0.0
# 1          Lime           0.0
# 2          Lime           0.0
# 3          Lime           0.0
# 4          Lime           0.0
# ..          ...           ...
# 656        Lime           0.0
# 657        Lime           0.0
# 658        Lime           0.0
# 659        Lime           0.0
# 660        Lime           0.0
#
# [661 rows x 2 columns]

# %%
query11 ='''
SELECT companyname, tripduration 
FROM trips
WHERE tripduration < 0.6000
AND companyname = 'Bolt Mobility'
ORDER BY companyname ASC;
'''

with engine.connect() as connection:    
    Q2_time_under_minute_Bolt = pd.read_sql(text(query11), con = connection)

# %%
Q2_time_under_minute_Bolt
# Out:
# Empty DataFrame
# Columns: [companyname, tripduration]
# Index: []

# %%
query12 ='''
SELECT companyname, tripduration 
FROM trips
WHERE tripduration < 0.6000
AND companyname = 'Gotcha'
ORDER BY companyname ASC;
'''

with engine.connect() as connection:    
    Q2_time_under_minute_Gotcha = pd.read_sql(text(query12), con = connection)

# %%
Q2_time_under_minute_Gotcha
# Out:
# Empty DataFrame
# Columns: [companyname, tripduration]
# Index: []

# %% [markdown]
# Companies that DID remove trips under a minute:
# Gotcha, Jump, and Bolt

# %% [markdown]
# Companies that DID NOT remove trips under a minute: Lime, Jump, Spin, and Lyft

# %% [markdown]
# 2. Trip lengths are capped at 24 hours

# %%
query13 = '''
SELECT tripduration, companyname
FROM trips
WHERE tripduration > 1440.0000
'''

with engine.connect() as connection:    
    Q2_over24hours = pd.read_sql(text(query13), con = connection)

# %%
Q2_over24hours
# Out:
#       tripduration    companyname
# 0       1469.00000  Bolt Mobility
# 1       3164.00000  Bolt Mobility
# 2       2961.00000  Bolt Mobility
# 3       1460.00000  Bolt Mobility
# 4       1523.00000  Bolt Mobility
# ...            ...            ...
# 6933    4859.00000  Bolt Mobility
# 6934    1611.10275           Lyft
# 6935    5083.00000  Bolt Mobility
# 6936    4877.00000  Bolt Mobility
# 6937    4324.00000  Bolt Mobility
#
# [6938 rows x 2 columns]

# %%
query = ''' SELECT * 
FROM trips
WHERE tripduration >= 1.0 AND tripduration <= 1440;
'''

with engine.connect() as connection:
        cleaned_trips = pd.read_sql(text(query), con = connection)
        
cleaned_trips
# Out:
#                   pubtimestamp companyname triprecordnum        sumdid  \
# 0      2019-06-26 19:18:17.223        Bird       BRD1107  PoweredAZRVL
# 1      2019-06-26 19:18:17.223        Bird       BRD1109  Powered89UBD
# 2      2019-06-26 19:18:17.223        Bird       BRD1108  PoweredPN85S
# 3      2019-06-26 19:18:17.223        Bird       BRD1111  Powered4PDHT
# 4      2019-06-26 19:18:17.223        Bird       BRD1114  PoweredL1I49
# ...                        ...         ...           ...           ...
# 549425 2019-06-26 19:18:17.223        Bird       BRD1113  PoweredVQHWJ
# 549426 2019-06-26 19:18:17.223        Bird       BRD1104  PoweredE51XY
# 549427 2019-06-26 19:18:17.223        Bird       BRD1112  PoweredM8VDW
# 549428 2019-06-26 19:18:17.223        Bird       BRD1106  PoweredR6YG5
# 549429 2019-06-26 19:58:19.153        Bird       BRD1242  Powered23WB2
#
#         tripduration  tripdistance   startdate        starttime     enddate  \
# ...

# %%
cleaned_trips.to_csv('cleaned_trips', index = False)

# %%
q1= '''

SELECT companyname, COUNT(tripduration)
FROM trips
WHERE tripduration <= 1.0 
GROUP BY companyname
'''


with engine.connect() as connection: 
    trip_less_than_1 = pd.read_sql(text(q1), con = connection) 
    
trip_less_than_1
# Out:
#   companyname  count
# 0        Bird   9321
# 1      Gotcha    564
# 2        Lime   2125
# 3        Lyft   4530

# %%
sns.set_style('whitegrid')

# %%
trip_less_than_1.plot.bar(x='companyname', y='count', rot=0,color='#57606c')

plt.legend(['Number per Company'])
plt.title('Trips less than 1 minute by Company',                              
         fontsize = 12, fontweight = 'bold')
plt.xlabel("")
# Out:
# Text(0.5, 0, '')

# %%
q2= '''

SELECT companyname, COUNT(tripduration)
FROM trips
WHERE tripduration >= 1440
GROUP BY companyname
'''


with engine.connect() as connection: 
    trips_more_than_24 = pd.read_sql(text(q2), con = connection) 
    
trips_more_than_24
# Out:
#      companyname  count
# 0  Bolt Mobility   6917
# 1           JUMP     27
# 2           Lyft      2
# 3           SPIN     28

# %%
trips_more_than_24.plot.bar(x='companyname', y='count', rot=0,color='#57606c')

plt.legend(['Number per Company'])
plt.title('Trips more than 24 Hours by Company',                              
         fontsize = 12, fontweight = 'bold')
plt.xlabel("")
# Out:
# Text(0.5, 0, '')

# %%
q4= '''

SELECT companyname, COUNT(tripduration)
FROM trips
WHERE tripduration >= 1440 OR tripduration <= 1.0 
GROUP BY companyname
'''


with engine.connect() as connection: 
     noncompliance_trips = pd.read_sql(text(q4), con = connection) 
    
noncompliance_trips
# Out:
#      companyname  count
# 0           Bird   9321
# 1  Bolt Mobility   6917
# 2         Gotcha    564
# 3           JUMP     27
# 4           Lime   2125
# 5           Lyft   4532
# 6           SPIN     28

# %%
noncompliance_trips.plot.bar(x='companyname', y='count', rot=0,color='#57606c')
plt.title('Companies out of compliance',                              
         fontsize = 12, fontweight = 'bold')
plt.xlabel("")
# Out:
# Text(0.5, 0, '')
